# %% [markdown]
# # 1. 라이브러리 & 전처리 된 데이터셋 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

train_data = pd.read_csv('/Users/hyunhonoh/Google Drive/My Drive/02. AIFFEL/datathon/sf_Crime_first/Data/train_preprocessed.csv')
# test_data = pd.read_csv('/Users/hyunhonoh/Google Drive/My Drive/02. AIFFEL/datathon/sf_Crime_first/Data/test_preprocessed.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # 2. 데이터 2차 전처리 - 절도 범죄만 추출

# %%
# train_data 데이터셋을 train 변수에 할당
train = train_data
# test = test_data

# %%
# 확인용
train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y  year  month  day  hour  minute  second  weekday  \
# 0 -122.425892  37.774599  2015      5   13    23      53       0        0
# 1 -122.425892  37.774599  2015      5   13    23      53       0        0
# 2 -122.424363  37.800414  2015      5   13    23      33       0        0
# 3 -122.426995  37.800873  2015      5   13    23      30       0        0
# 4 -122.438738  37.771541  2015      5   13    23      30       0        0
#
#    season
# 0  spring
# 1  spring
# 2  spring
# 3  spring
# 4  spring

# %%
# 원본 데이터셋의 카테고리 종류
train_data['Category'].unique()
# Out:
# array(['WARRANTS', 'OTHER OFFENSES', 'LARCENY/THEFT', 'VEHICLE THEFT',
#        'VANDALISM', 'NON-CRIMINAL', 'ROBBERY', 'ASSAULT', 'WEAPON LAWS',
#        'BURGLARY', 'SUSPICIOUS OCC', 'DRUNKENNESS',
#        'FORGERY/COUNTERFEITING', 'DRUG/NARCOTIC', 'STOLEN PROPERTY',
#        'SECONDARY CODES', 'TRESPASS', 'MISSING PERSON', 'FRAUD',
#        'KIDNAPPING', 'RUNAWAY', 'DRIVING UNDER THE INFLUENCE',
#        'SEX OFFENSES FORCIBLE', 'PROSTITUTION', 'DISORDERLY CONDUCT',
#        'ARSON', 'FAMILY OFFENSES', 'LIQUOR LAWS', 'BRIBERY',
#        'EMBEZZLEMENT', 'SUICIDE', 'LOITERING',
#        'SEX OFFENSES NON FORCIBLE', 'EXTORTION', 'GAMBLING', 'BAD CHECKS',
#        'TREA', 'RECOVERED VEHICLE', 'PORNOGRAPHY/OBSCENE MAT'],
#       dtype=object)

# %%
# Category 컬럼에서 '절도' 유형에 속하는 항목 리스트
# list_theft = ['LARCENY/THEFT', 'VEHICLE THEFT', 'BURGLARY', 'ROBBERY', 'STOLEN PROPERTY', 'RECOVERED VEHICLE', 'EMBEZZLEMENT']
# list_theft = ['LARCENY/THEFT']

# %% [markdown]
# #### 절도 종류 및 설명
# 1. Larceny/theft : 절도, 도둑질
# 2. Vehicle Theft : 차량 절도
# 3. Burglary : 건물에 들어가서 훔쳐오는 절도
# 4. Robbery : 강도
# 5. Stolen Property : 재물 절도
# 6. Recovered Vehicle :
# 7. Embezzlement : 횡령

# %%
# list_theft in train['Category']
# train_theft_bool = train['Category'].apply(lambda x: x in list_theft)
# train = train[train_theft_bool].reset_index(drop=True)                               # train_theft에 해당하는 행만 추출후 인덱스 정렬
train
# Out:
#                       Dates                Category  \
# 0       2015-05-13 23:53:00                WARRANTS
# 1       2015-05-13 23:53:00          OTHER OFFENSES
# 2       2015-05-13 23:33:00          OTHER OFFENSES
# 3       2015-05-13 23:30:00           LARCENY/THEFT
# 4       2015-05-13 23:30:00           LARCENY/THEFT
# ...                     ...                     ...
# 875721  2003-01-06 00:15:00                 ROBBERY
# 875722  2003-01-06 00:01:00           LARCENY/THEFT
# 875723  2003-01-06 00:01:00           LARCENY/THEFT
# 875724  2003-01-06 00:01:00               VANDALISM
# 875725  2003-01-06 00:01:00  FORGERY/COUNTERFEITING
#
#                                          Descript  DayOfWeek PdDistrict  \
# 0                                  WARRANT ARREST  Wednesday   NORTHERN
# 1                        TRAFFIC VIOLATION ARREST  Wednesday   NORTHERN
# 2                        TRAFFIC VIOLATION ARREST  Wednesday   NORTHERN
# 3                    GRAND THEFT FROM LOCKED AUTO  Wednesday   NORTHERN
# 4                    GRAND THEFT FROM LOCKED AUTO  Wednesday       PARK
# ...                                           ...        ...        ...
# 875721           ROBBERY ON THE STREET WITH A GUN     Monday    TARAVAL
# 875722               GRAND THEFT FROM LOCKED AUTO     Monday  INGLESIDE
# 875723               GRAND THEFT FROM LOCKED AUTO     Monday   SOUTHERN
# 875724  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Monday   SOUTHERN
# 875725                   CHECKS, FORGERY (FELONY)     Monday    BAYVIEW
#
#             Resolution                     Address           X          Y  \
# 0       ARREST, BOOKED          OAK ST / LAGUNA ST -122.425892  37.774599
# 1       ARREST, BOOKED          OAK ST / LAGUNA ST -122.425892  37.774599
# 2       ARREST, BOOKED   VANNESS AV / GREENWICH ST -122.424363  37.800414
# 3                 NONE    1500 Block of LOMBARD ST -122.426995  37.800873
# 4                 NONE   100 Block of BRODERICK ST -122.438738  37.771541
# ...                ...                         ...         ...        ...
# 875721            NONE  FARALLONES ST / CAPITOL AV -122.459033  37.714056
# 875722            NONE        600 Block of EDNA ST -122.447364  37.731948
# 875723            NONE          5TH ST / FOLSOM ST -122.403390  37.780266
# 875724            NONE        TOWNSEND ST / 2ND ST -122.390531  37.780607
# 875725            NONE    1800 Block of NEWCOMB AV -122.394926  37.738212
#
#         year  month  day  hour  minute  second  weekday  season
# 0       2015      5   13    23      53       0        0  spring
# 1       2015      5   13    23      53       0        0  spring
# 2       2015      5   13    23      33       0        0  spring
# 3       2015      5   13    23      30       0        0  spring
# 4       2015      5   13    23      30       0        0  spring
# ...      ...    ...  ...   ...     ...     ...      ...     ...
# 875721  2003      1    6     0      15       0        0  winter
# 875722  2003      1    6     0       1       0        0  winter
# 875723  2003      1    6     0       1       0        0  winter
# 875724  2003      1    6     0       1       0        0  winter
# 875725  2003      1    6     0       1       0        0  winter
#
# [875726 rows x 17 columns]

# %% [markdown]
# - 데이터 개수 : 296,447개 (원본 878,049개)

# %% [markdown]
# # 3. 시각화

# %% [markdown]
# ## 3.1 범죄 유형별 범죄 발생 수

# %%
# 도화지 그리기
fig, axs = plt.subplots(figsize=(10, 8))

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

#
train['Category']

# countplot 그리기
sns.countplot(y=train['Category'], palette='husl', order=train['Category'].value_counts().index)

# 라벨, 제목, 틱 설정
container = axs.containers[0]
# axs.bar_label(container, label=[f'{x:,.0f}' for x in container.datavalues], label_type='center')
plt.xticks(rotation = 45)
plt.ylabel('Frequency')
plt.title('Crime by Category')
plt.show()

# %% [markdown]
# - LARCENY/THEFT는 특히 절도 범죄 외의 전체 범죄 중에 가장 많았다
# - 왜 샌프란시스코에서는 다른 종류의 범죄보다 절도 범죄가 많은지 확인이 필요하다

# %% [markdown]
# ## 3.2 연도별 범죄발생 추이

# %%
# 도화지
fig = plt.figure(figsize=(10, 8))

# 연도별 범죄수 세기
year_category = train['Category'].groupby(train['year']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
plt.plot(year_category)

# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Crime Number by Year')
plt.show()

# %% [markdown]
# - 약 2005년부터 범죄수가 떨어지기 시작하여 2010년까지 범죄가 최저를 기록했다
# - 그런데 2010년부터 급격하게 다시 절도 범죄가 증가하는 추세를 보이고 있다
# - 왜 2005년부터 2010년까지 범죄가 감소했고 그 이후에는 증가하게 되었는지 원인 분석이 필요하다

# %% [markdown]
# ## 3.3 월별 범죄발생 추이

# %%
# 도화지
fig = plt.figure(figsize=(10, 8))

# 연도별 범죄수 세기
year_category = train['Category'].groupby(train['month']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
plt.plot(year_category)

# 라벨, 제목, 틱 설정
container = axs.containers[0]
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Crime Number by Month')
plt.show()

# %% [markdown]
# - 4, 5, 10월에 유독 절도 범죄가 높았다
# - 어떤 요인으로 범죄수가 봄과 가을에 증가했는지 살펴봐야겠다
# - 계절적 요인일 수도 있으니 다음은 계절에 관련하여 그래프로 확인하겠다

# %% [markdown]
# ## 3.4 일별 범죄발생 추이

# %%
# 도화지
fig = plt.figure(figsize=(10, 8))

# 연도별 범죄수 세기
day_category = train['Category'].groupby(train['day']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
plt.plot(day_category)

# 라벨, 제목, 틱 설정
container = axs.containers[0]
plt.xlabel('day')
plt.ylabel('Count')
plt.title('Crime Number by Day')
plt.show()

# %% [markdown]
# - 31일이 낮은 이유 : 1, 3, 5, 7, 8, 10, 12월에만 존재하기 때문
# - 2일이 가장 낮음

# %% [markdown]
# ## 3.5 시간별 범죄발생 추이

# %%
# 도화지
fig = plt.figure(figsize=(10, 8))

# 연도별 범죄수 세기
hour_category = train['Category'].groupby(train['hour']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
plt.plot(hour_category)

# 라벨, 제목, 틱 설정
container = axs.containers[0]
plt.xlabel('hour')
plt.ylabel('Count')
plt.title('Crime Number by Hour')
plt.show()

# %% [markdown]
# ## 3.6 분별 범죄발생 추이

# %%
# 도화지
fig = plt.figure(figsize=(10, 8))

# 연도별 범죄수 세기
minute_category = train['Category'].groupby(train['minute']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
plt.plot(minute_category)

# 라벨, 제목, 틱 설정
container = axs.containers[0]
plt.xlabel('minute')
plt.ylabel('Count')
plt.title('Crime Number by Minute')
plt.show()

# %% [markdown]
# - 정각과 30분에 범죄 발생이 높음

# %% [markdown]
# ## 3.6 요일별 범죄발생 추이

# %%
# 도화지
fig = plt.figure(figsize=(10, 8))


# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})


# 연도별 범죄수 그래프
axs = sns.countplot(x=train['DayOfWeek'], palette='husl', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# 라벨, 제목, 틱 설정
container = axs.containers[0]
plt.xlabel('DayOfWeek')
plt.ylabel('Count')
plt.title('Crime Number by DayOfWeek')
plt.show()

# %% [markdown]
# ## 3.6.1 카테고리 유형별 요일별 범죄수

# %%
# 도화지와 축 설정
fig, axs = plt.subplots(4, 2, figsize=(20, 15))

# 요일 리스트
week_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# 카테고리 유형 리스트
category_list = train['Category'].value_counts().index

# 그래프 그리기
i = 0
for row in range(4):
    for col in range(2):
        if i > 6:
            break
        cate = train[train['Category'] == category_list[i]]
        ax = sns.countplot(x=cate['DayOfWeek'], ax=axs[row][col], order=week_list)
        axs[row][col].set(xlabel = category_list[i])        
        i += 1

# %% [markdown]
# - 대부분 금요일에 범죄수가 많다
# - LARCENY/THEFT, ROBBERY 주말도 많다

# %% [markdown]
# ## 3.7 계절별 범죄발생 수

# %%
# 도화지 그리기
fig = plt.figure(figsize=(10, 8))

# 계절별 범죄수
axs = sns.countplot(x=train['season'], palette='husl', order=['spring', 'summer', 'fall', 'winter'])


# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 라벨, 제목, 틱 설정
container = axs.containers[0]
axs.bar_label(container, label=[f'{x:,.0f}' for x in container.datavalues], label_type='center')
plt.xlabel('Season')
plt.ylabel('Count')
plt.title('Crime Number by Season')

plt.show()

# %% [markdown]
# - 계절에 따른 절도 범죄의 수는 거의 일정하므로 계절 데이터로는 유의미한 원인을 찾을 수 없다

# %% [markdown]
# ## 3.8 히트맵으로 보기

# %%
# 히트맵 계산하기 
train_heat = train.groupby(['Category', 'DayOfWeek'])['Dates'].count()
train_heat_pivot = train_heat.unstack()
train_heat_pivot
# Out:
# DayOfWeek                     Friday   Monday  Saturday   Sunday  Thursday  \
# Category
# ARSON                          220.0    228.0     219.0    211.0     199.0
# ASSAULT                      11155.0  10550.0   11987.0  12070.0   10236.0
# BAD CHECKS                      62.0     66.0      45.0     20.0      66.0
# BRIBERY                         49.0     41.0      42.0     41.0      39.0
# BURGLARY                      6302.0   5239.0    4732.0   4205.0    5336.0
# DISORDERLY CONDUCT             540.0    607.0     624.0    584.0     643.0
# DRIVING UNDER THE INFLUENCE    352.0    263.0     457.0    442.0     282.0
# DRUG/NARCOTIC                 7415.0   7812.0    6385.0   6138.0    8447.0
# DRUNKENNESS                    621.0    512.0     833.0    813.0     496.0
# EMBEZZLEMENT                   211.0    222.0     137.0    108.0     165.0
# EXTORTION                       35.0     30.0      32.0     39.0      40.0
# FAMILY OFFENSES                 80.0     69.0      59.0     54.0      63.0
# FORGERY/COUNTERFEITING        1752.0   1702.0    1177.0    900.0    1608.0
# FRAUD                         2633.0   2526.0    2249.0   1871.0    2345.0
# GAMBLING                        35.0     16.0      21.0     12.0      20.0
# KIDNAPPING                     385.0    340.0     355.0    373.0     289.0
# LARCENY/THEFT                27025.0  23505.0   27121.0  24055.0   24339.0
# LIQUOR LAWS                    288.0    188.0     297.0    222.0     247.0
# LOITERING                      139.0    191.0     140.0    154.0     186.0
# MISSING PERSON                4602.0   3557.0    3702.0   3026.0    3643.0
# NON-CRIMINAL                 13926.0  12819.0   13940.0  12909.0   12773.0
# OTHER OFFENSES               18546.0  17765.0   17105.0  15438.0   18444.0
# PORNOGRAPHY/OBSCENE MAT          4.0      3.0       1.0      3.0       5.0
# PROSTITUTION                  1155.0    408.0     848.0    619.0    1536.0
# RECOVERED VEHICLE              494.0    529.0     343.0    307.0     429.0
# ROBBERY                       3382.0   3192.0    3426.0   3283.0    3214.0
# RUNAWAY                        329.0    276.0     261.0    199.0     297.0
# SECONDARY CODES               1392.0   1479.0    1462.0   1542.0    1389.0
# SEX OFFENSES FORCIBLE          620.0    605.0     661.0    688.0     585.0
# SEX OFFENSES NON FORCIBLE       28.0     23.0      21.0     16.0      15.0
# STOLEN PROPERTY                647.0    636.0     581.0    583.0     678.0
# SUICIDE                         72.0     75.0      73.0     67.0      89.0
# SUSPICIOUS OCC                4921.0   4445.0    4154.0   4008.0    4504.0
# TREA                             1.0      1.0       2.0      NaN       1.0
# TRESPASS                      1062.0   1080.0     982.0    915.0    1046.0
# VANDALISM                     7071.0   5916.0    7301.0   6577.0    5968.0
# VEHICLE THEFT                 8597.0   7401.0    8108.0   7496.0    7449.0
# WARRANTS                      5921.0   5804.0    5355.0   5279.0    6365.0
# WEAPON LAWS                   1302.0   1182.0    1231.0   1127.0    1281.0
#
# DayOfWeek                    Tuesday  Wednesday
# Category
# ARSON                          235.0      200.0
# ASSAULT                      10268.0    10549.0
# BAD CHECKS                      76.0       71.0
# BRIBERY                         37.0       40.0
# BURGLARY                      5356.0     5430.0
# DISORDERLY CONDUCT             657.0      658.0
# DRIVING UNDER THE INFLUENCE    251.0      221.0
# DRUG/NARCOTIC                 8463.0     9259.0
# DRUNKENNESS                    461.0      541.0
# EMBEZZLEMENT                   156.0      165.0
# EXTORTION                       39.0       41.0
# FAMILY OFFENSES                 84.0       79.0
# FORGERY/COUNTERFEITING        1750.0     1703.0
# FRAUD                         2497.0     2516.0
# GAMBLING                        12.0       30.0
# KIDNAPPING                     306.0      292.0
# LARCENY/THEFT                23872.0    24403.0
# LIQUOR LAWS                    323.0      334.0
# LOITERING                      238.0      159.0
# MISSING PERSON                3611.0     3528.0
# NON-CRIMINAL                 12679.0    12869.0
# OTHER OFFENSES               18755.0    19907.0
# PORNOGRAPHY/OBSCENE MAT          3.0        3.0
# PROSTITUTION                  1408.0     1472.0
# RECOVERED VEHICLE              515.0      515.0
# ROBBERY                       3219.0     3272.0
# RUNAWAY                        271.0      261.0
# SECONDARY CODES               1343.0     1372.0
# SEX OFFENSES FORCIBLE          595.0      626.0
# SEX OFFENSES NON FORCIBLE       23.0       22.0
# STOLEN PROPERTY                713.0      699.0
# SUICIDE                         66.0       66.0
# SUSPICIOUS OCC                4513.0     4849.0
# TREA                             1.0        NaN
# TRESPASS                      1113.0     1120.0
# VANDALISM                     5844.0     5904.0
# VEHICLE THEFT                 7262.0     7393.0
# WARRANTS                      6412.0     7009.0
# WEAPON LAWS                   1176.0     1251.0

# %%
# 히트맵 
plt.figure(figsize=(10,8))

sns.heatmap(data = train_heat_pivot, fmt = '.2f', linewidths=0.5, )
# Out:
# <AxesSubplot: xlabel='DayOfWeek', ylabel='Category'>

# %% [markdown]
# - LARCENY/THEFT는 금요일 토요일에 가장 높음을 알 수 있다

# %% [markdown]
# ## 3.9 위도 경도 시각화

# %%
# 위도, 경도 좌표로 그래프 그리기
plt.figure(figsize=(10,8))

sns.scatterplot(x=train['X'], y=train['Y'])
# Out:
# <AxesSubplot: xlabel='X', ylabel='Y'>

# %% [markdown]
# - 이상치(Outlier) 발견
# - 이상치 제거해야 함

# %% [markdown]
# ### Outlier 제거

# %%
# 좌표에서 가장 큰 값(이상치)을 확인
train['X'].max(), train['Y'].max()
# Out:
# (-120.5, 90.0)

# %%
# 경도 -122보다 낮은 값들만 추출
train = train[train['X'] < -122]
train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y  year  month  day  hour  minute  second  weekday  \
# 0 -122.425892  37.774599  2015      5   13    23      53       0        0
# 1 -122.425892  37.774599  2015      5   13    23      53       0        0
# 2 -122.424363  37.800414  2015      5   13    23      33       0        0
# 3 -122.426995  37.800873  2015      5   13    23      30       0        0
# 4 -122.438738  37.771541  2015      5   13    23      30       0        0
#
#    season
# 0  spring
# 1  spring
# 2  spring
# 3  spring
# 4  spring

# %% [markdown]
# ### 시각화

# %%
# 도화지 그리기
plt.figure(figsize=(10,8))

# 그래프 그리기
sns.scatterplot(x=train['X'], y=train['Y'], hue=train['Category'])

# 라벨, 제목, 틱 설정
plt.title('Location')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')
# /usr/local/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 3.10 행정구역별 범죄현황

# %%
train['PdDistrict'].value_counts()

sns.countplot(y=train['PdDistrict'], order=train['PdDistrict'].value_counts().index)
plt.xticks(rotation=45)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000., 120000.,
#         140000., 160000., 180000.]),
#  [Text(0.0, 0, '0'),
#   Text(20000.0, 0, '20000'),
#   Text(40000.0, 0, '40000'),
#   Text(60000.0, 0, '60000'),
#   Text(80000.0, 0, '80000'),
#   Text(100000.0, 0, '100000'),
#   Text(120000.0, 0, '120000'),
#   Text(140000.0, 0, '140000'),
#   Text(160000.0, 0, '160000'),
#   Text(180000.0, 0, '180000')])

# %%
# 도화지 그리기
plt.figure(figsize=(10,8))

# 그래프 그리기
sns.scatterplot(data=train, x='X', y='Y', hue='PdDistrict')

# 라벨, 제목, 틱 설정
plt.title('Location')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')
# /usr/local/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.lmplot(data=train, x='X', y='Y', hue='PdDistrict')

# %% [markdown]
# ## 3.11 행정구역별 범죄유형별 범죄수

# %%
# 도화지와 축 설정
fig, axs = plt.subplots(4, 2, figsize=(20, 15))

# 요일 리스트
# week_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# 카테고리 유형 리스트
pd_distirct_list = train['PdDistrict'].value_counts().index

# 그래프 그리기
i = 0
for row in range(6):
    for col in range(2):
        # if i > 10:
        #     break
        pd_dis = train[train['PdDistrict'] == pd_distirct_list[i]]
        ax = sns.countplot(y=pd_dis['Category'], ax=axs[row][col], order=train['Category'].value_counts().index)
        axs[row][col].set(xlabel = pd_distirct_list[i])
        i += 1

# %%
# 도화지와 축 설정
fig, axs = plt.subplots(4, 2, figsize=(20, 15))

# 요일 리스트
# week_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# 카테고리 유형 리스트
pd_distirct_list = train['PdDistrict'].value_counts().index

# 그래프 그리기
i = 0
for row in range(4):
    for col in range(2):
        if i > 6:
            break
        pd_dis = train[train['PdDistrict'] == pd_distirct_list[i]]
        ax = sns.countplot(y=pd_dis['Category'], ax=axs[row][col], order=train['Category'].value_counts().index)
        axs[row][col].set(xlabel = pd_distirct_list[i])
        i += 1

# %% [markdown]
# ## 3.12 범죄유형별 관할별 범죄수

# %%
# 도화지와 축 설정
fig, axs = plt.subplots(4, 2, figsize=(20, 15))

# 요일 리스트
# week_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# 카테고리 유형 리스트
category_list = train['Category'].value_counts().index

# 그래프 그리기
i = 0
for row in range(4):
    for col in range(2):
        if i > 6:
            break
        cate = train[train['Category'] == category_list[i]]
        ax = sns.countplot(y=cate['PdDistrict'], ax=axs[row][col], order=train['PdDistrict'].value_counts().index)
        axs[row][col].set(ylabel = category_list[i])
        i += 1

# %%
larceny = train[train['Category'] == 'LARCENY/THEFT']
non_larceny = train[train['Category'] != 'LARCENY/THEFT']


plt.plot()

# %%
# 도화지
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# 연도별 범죄수 세기
non_year_category = non_larceny['Category'].groupby(non_larceny['year']).count()
year_category = larceny['Category'].groupby(larceny['year']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
sns.lineplot(data=non_year_category, label='Others', ax=axs[0])
sns.lineplot(data=year_category, c='r', label='Larceny', ax=axs[1])


# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('year')
plt.ylabel('Count')
plt.title('Crime Number by Year')
plt.show()

# %%
# 도화지
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# 연도별 범죄수 세기
non_month_category = non_larceny['Category'].groupby(non_larceny['month']).count()
month_category = larceny['Category'].groupby(larceny['month']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
sns.lineplot(data=non_month_category, label='Others', ax=axs[0])
sns.lineplot(data=month_category, c='r', label='Larceny', ax=axs[1])


# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Crime Number by Month')
plt.show()

# %%
# 도화지
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# 연도별 범죄수 세기
non_day_category = non_larceny['Category'].groupby(non_larceny['day']).count()
day_category = larceny['Category'].groupby(larceny['day']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
sns.lineplot(data=non_day_category, label='Others', ax=axs[0])
sns.lineplot(data=day_category, c='r', label='Larceny', ax=axs[1])


# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('Day')
plt.ylabel('Count')
plt.title('Crime Number by Day')
plt.show()

# %%
# 도화지
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# 연도별 범죄수 세기
non_hour_category = non_larceny['Category'].groupby(non_larceny['hour']).count()
hour_category = larceny['Category'].groupby(larceny['hour']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
sns.lineplot(data=non_hour_category, label='Others', ax=axs[0])
sns.lineplot(data=hour_category, c='r', label='Larceny', ax=axs[1])


# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('Hour')
plt.ylabel('Count')
plt.title('Crime Number by Hour')
plt.show()

# %%
# 도화지
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# 연도별 범죄수 세기
non_minute_category = non_larceny['Category'].groupby(non_larceny['minute']).count()
minute_category = larceny['Category'].groupby(larceny['minute']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
sns.lineplot(data=non_minute_category, label='Others', ax=axs[0])
sns.lineplot(data=minute_category, c='r', label='Larceny', ax=axs[1])


# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('Minute')
plt.ylabel('Count')
plt.title('Crime Number by Minute')
plt.show()

# %%
# 도화지
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# 연도별 범죄수 세기
non_season_category = non_larceny['Category'].groupby(non_larceny['season']).count()
season_category = larceny['Category'].groupby(larceny['season']).count()

# 그리드, 그리드 색 설정
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# 연도별 범죄수 그래프
sns.lineplot(data=non_season_category, label='Others', ax=axs[0], )
sns.lineplot(data=season_category, c='r', label='Larceny', ax=axs[1])


# 라벨, 제목, 틱 설정
# container = axs.containers[0]
plt.xlabel('Season')
plt.ylabel('Count')
plt.title('Crime Number by Season')
plt.show()

# %%
non_season_category['season'].value_counts().index
